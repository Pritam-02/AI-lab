# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import skfuzzy as fuzz

# %%
#df = pd.read_csv('./mtcars.csv')
df = pd.read_csv('./housing.csv')
print(df.columns)

#df = df.drop('model', axis =1) #use to drop column 'model' from 'mtcars' dataset

X = df.values

Xt = X.astype(np.float64).T # transposed X
c = 2 # number of clusters
# Out:
# Index(['RM', 'LSTAT', 'PTRATIO', 'MEDV'], dtype='str')

# %%
ctr, u,_, _, _, _ ,fpr = fuzz.cluster.cmeans(
    Xt, c, m=2, error=0.005, maxiter = 2000
)

print(u)
# Out:
# [[5.99662582e-01 8.73146393e-01 3.24158302e-02 1.30551453e-02
#   5.86409661e-02 6.61384066e-02 7.43447547e-01 1.89568663e-01
#   9.92794643e-01 9.92380021e-01 9.72603495e-01 9.92380021e-01
#   8.64970784e-01 9.48407713e-01 9.99050486e-01 9.68429944e-01
#   7.19248576e-01 9.99586799e-01 9.57141175e-01 9.99050486e-01
#   9.48698176e-01 9.77693077e-01 9.75737734e-01 9.64389420e-01
#   9.81672757e-01 9.54019235e-01 9.93782898e-01 9.69376585e-01
#   9.97847749e-01 9.15904413e-01 9.32484439e-01 9.64389420e-01
#   9.41520423e-01 9.39716561e-01 9.46910935e-01 9.92380021e-01
#   9.64900411e-01 9.15904412e-01 4.99352045e-01 3.80534002e-03
#   3.57617884e-02 2.43806807e-01 4.13170500e-01 4.99352044e-01
#   9.02833536e-01 9.85100139e-01 9.64900411e-01 9.93782898e-01
#   9.62693533e-01 9.82826875e-01 9.74819991e-01 9.43660814e-01
#   4.56014353e-01 6.81149099e-01 9.92380021e-01 4.43806536e-02
#   4.99352044e-01 9.63663582e-08 6.94074779e-01 9.77693077e-01
# ...

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.scatter(ctr[:, 0], ctr[:, 1], marker='X')
plt.title("Fuzzy C-Means Clustering")
plt.show()

# %% [markdown]
# ALGO
# 1. given the data points based on the no. of clusters required initialize the membership table with random value
# 2. calculate centroide Vij=(∑k=1 to n μik^m * Xk)/(∑k=1 to n μik^m), μ is membership value, m is fuzziness parameter, Xk is data point.
# 3. find the euclidean distance of each point from centroid.
# 4. updating membership values. μki=((∑j=1 to n(Dki/Dkj)^2)^(1/m-1))^-1
# 5. repeat steps 2 to 4 untill the cost values are obtained for the membership values or difference less than tolarancxe value.
