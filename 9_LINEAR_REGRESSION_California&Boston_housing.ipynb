# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# df = fetch_california_housing(as_frame=True)
# X= df.data
# y = df.target


df = pd.read_csv('./housing.csv')

print(df.columns)

X = df.drop('RM', axis=1)
y = df['RM']
# Out:
# Index(['RM', 'LSTAT', 'PTRATIO', 'MEDV'], dtype='str')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 42, test_size=0.2)
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"MSE: {mse}")
print(f"R2 Score: {r2}")
# Out:
# MSE: 0.1506922174307209
# R2 Score: 0.39356725533834935

# %%
plt.scatter(y_test, y_pred)
plt.title("Scatter Plot")
plt.xlabel("Test Value")
plt.ylabel("Predicted Value")
plt.show()

# %% [markdown]
# eqn fo linear regression is Y=mX+b
# where y= dependent variable, x=independent variable, m is the slope of the line(how muchY changes for a unit change in X), b= intercept(the value of Y when x =0 )
#
#
# diameter(x) price(Y) mean(X) mean(Y) deviation(X) dev(Y) product_of_deviation(X*Y)  sum_of_product_of_deviation   square_of_deviation_for_X
#
# 8           10         10    13      -2           -3            6                       12                              4
#
# 10          13                        0            0            0                                                       0
#
# 12          16                        2            3            6                                                       4
#
# calculate m =(sum of product deviation)/(sum of the square of the deviatiuon X)= 12/8= 1.5
# calculate b= mean of Y-(m* mean of X)= 13-(1.5*10)= -2
